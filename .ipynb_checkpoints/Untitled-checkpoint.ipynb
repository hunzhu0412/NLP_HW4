# %%
import numpy as np
import pandas as pd
import json

# %%
def loadData(papers,path):
    file = open(path, 'r', encoding='utf-8')

    for line in file.readlines():
        dic = json.loads(line)
        papers.append(dic)

# %%
papers = []

folders = ['AA','AB','AC','AD','AE','AF','AG','AH','AI','AJ','AK','AL','AM']
nums = ['00','01','02','03','04','05','06','07','08','09']
for i in range(10,100):
    nums.append(i.__str__())
srt = '../wiki_zh/'

for folder in folders:
    tmp = srt+folder
    for n in nums:
        if folder == 'AM' and n == '74':
            break
        path = tmp+'/wiki_'+n
        loadData(papers,path)

# %%
pd.DataFrame(papers)
# Out:
#               id                                          url       title  \
# 0             13       https://zh.wikipedia.org/wiki?curid=13          数学
# 1             18       https://zh.wikipedia.org/wiki?curid=18          哲学
# 2             21       https://zh.wikipedia.org/wiki?curid=21          文学
# 3             22       https://zh.wikipedia.org/wiki?curid=22          历史
# 4             25       https://zh.wikipedia.org/wiki?curid=25       计算机科学
# ...          ...                                          ...         ...
# 1043219  6458572  https://zh.wikipedia.org/wiki?curid=6458572          福晖
# 1043220  6458573  https://zh.wikipedia.org/wiki?curid=6458573          人形
# 1043221  6458575  https://zh.wikipedia.org/wiki?curid=6458575  成山（道光壬辰进士）
# 1043222  6458581  https://zh.wikipedia.org/wiki?curid=6458581         穆通阿
# 1043223  6458590  https://zh.wikipedia.org/wiki?curid=6458590        警察之家
#
#                                                       text
# 0        数学\n\n数学是利用符号语言研究数量、结构、变化以及空间等概念的一门学科，从某种角度看属于...
# 1        哲学\n\n哲学（）是研究普遍的、根本的问题的学科，包括存在、知识、价值、理智、心灵、语言等...
# 2        文学\n\n文学（），在最广泛的意义上，是任何单一的书面作品。\n\n更严格地说，文学写作被...
# 3        历史\n\n历史（现代汉语词汇，古典文言文称之为史），指人类社会过去的事件和行动，以及对这些...
# 4        计算机科学\n\n计算机科学（，有时缩写为）是系统性研究信息与计算的理论基础以及它们在计算机...
# ...                                                    ...
# 1043219  福晖\n\n福晖，原名福明（1796年 - ？），字子受，号镜如，又号仲芸，马佳氏，内务府正...
# 1043220                              人形\n\n人形可以指：\n⧼* 人偶\n
# 1043221  成山（道光壬辰进士）\n\n成山（1791年 - ？），字屏临，号进斋，满洲正蓝旗人。道光八...
# 1043222  穆通阿\n\n穆通阿（1794年 - ？），钮祜禄氏，字子理，号似山，满洲镶黄旗人。道光八年...
# 1043223  警察之家\n\n《警察之家》（；），是所撰写的「」的系列，目前已出至第二卷。而作者加藤之前已...
#
# [1043224 rows x 4 columns]
